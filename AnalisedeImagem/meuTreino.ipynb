# %%
from tensorflow.keras import utils

path = './Data/Data'
batch_size = 64

train = utils.image_dataset_from_directory(
    directory=path + '/Train',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path + '/Test',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)
# Out:
# Found 27455 files belonging to 24 classes.
# Found 7172 files belonging to 24 classes.

# %%
from tensorflow.keras import models, layers, activations, initializers

model = models.Sequential([
    layers.Input(shape=(28,28,3)), # 28x28x1

    layers.Conv2D(8, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.Conv2D(7, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.Conv2D(6, kernel_size=(3,3), strides=(1,1), padding='same'), # 10 @ 28x28
    layers.MaxPooling2D((3,3)),

    layers.Flatten(), # 7840
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()), # 64
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal()) # 24
])

from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 5
epochs = 100
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        ),
        callbacks .ModelCheckpoint(
            filepath = model_path,
            save_weights_only = False,
            monitor = 'loss',
            mode = 'min',
            save_best_only = True
        )
    ]
)

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        ),
        callbacks .ModelCheckpoint(
            filepath = model_path,
            save_weights_only = False,
            monitor = 'loss',
            mode = 'min',
            save_best_only = True
        )
    ]
)
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 1.5756 - sparse_categorical_accuracy: 0.6775 - val_loss: 0.8320 - val_sparse_categorical_accuracy: 0.7543
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.9857 - val_sparse_categorical_accuracy: 0.7879
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.9331 - val_sparse_categorical_accuracy: 0.8153
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.9579 - val_sparse_categorical_accuracy: 0.8201
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9909 - val_sparse_categorical_accuracy: 0.8190
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 5.0865e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0044 - val_sparse_categorical_accuracy: 0.8171
# Epoch 6: early stopping
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 3.3270e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0510 - val_sparse_categorical_accuracy: 0.8160
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 2.2489e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0758 - val_sparse_categorical_accuracy: 0.8183
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.6671e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1029 - val_sparse_categorical_accuracy: 0.8175
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.2228e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1106 - val_sparse_categorical_accuracy: 0.8186
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.1748 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.9899 - val_sparse_categorical_accuracy: 0.8126
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.9094 - val_sparse_categorical_accuracy: 0.8416
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 6.1177e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9365 - val_sparse_categorical_accuracy: 0.8441
# Epoch 8/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 2.9562e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9504 - val_sparse_categorical_accuracy: 0.8437
# Epoch 9/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 2.0127e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9667 - val_sparse_categorical_accuracy: 0.8456
# Epoch 10/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.4628e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9843 - val_sparse_categorical_accuracy: 0.8465
# Epoch 11/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.1079e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0007 - val_sparse_categorical_accuracy: 0.8470
# Epoch 11: early stopping
